# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiShra1/Computer-Vision-and-Image-Processing/blob/main/ImagePhaseSwapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a97ce0df-5797-406f-85e9-8f20d3d92f65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a97ce0df-5797-406f-85e9-8f20d3d92f65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CameraMan.png to CameraMan.png
# Saving lena.jpg to lena.jpg

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
lena = cv2.imread('/content/lena.jpg')/255
cameraMan= cv2.imread('/content/CameraMan.png')/255

# %%
plt.imshow(lena, cmap ='gray')
plt.title('Lena'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.imshow(cameraMan, cmap ='gray')
plt.title('Camera Man'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
#take fft of the two images
lenaFFT = np.fft.fft2(lena)
cameraManFFT = np.fft.fft2(cameraMan)

# getting the magnitude and phase of the images from FFT
magnitudeLena = np.abs(lenaFFT)
phaseLena= np.angle(lenaFFT)

magnitudeCameraMan= np.abs(cameraManFFT)
phaseCameraMan = np.angle(cameraManFFT)

# Swapping the phases of the two images
outputImag1 = magnitudeLena*np.exp(1j*phaseCameraMan)
outputImag2 = magnitudeCameraMan * np.exp(1j*phaseLena)


# Reconstructing the images using Inverse FFT
outputImag1 = np.abs(np.fft.ifft2(outputImag1))
outputImag2 = np.abs(np.fft.ifft2(outputImag2))

# %%
plt.imshow(outputImag1, cmap ='gray')
plt.title('Phase Swapped lena'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(outputImag2, cmap ='gray')
plt.title('Phase Swapped CameraMan'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
